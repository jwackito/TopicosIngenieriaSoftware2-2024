# %%
import pandas as pd
import rdflib
import numpy

df = pd.read_csv('dataset/raw.csv.gz', dialect='excel', keep_default_na=False, dtype=str, index_col=0)

DESDE = 1000
HASTA = 1100
subset_df = df.iloc[DESDE:HASTA]


contador = 0
for i in range(DESDE, HASTA):
    if(len(df.loc[i].dup_candidates.split())<2):contador+=1

print(contador)
# Out:
# 40

# %%
df.loc[1003].dup_candidates
# Out:
# '1003 7968'

# %%
# inicializo la lista con cadenas vacias que significa que aun no se reviso
revised = ['']*200

OFFSET =1000 # para que el indice de la lista sea el mismo que el del dataframe
for i in range(0,199):
    if(len(df.loc[i+OFFSET].dup_candidates.split())<2):
        revised[i] = df.loc[i+OFFSET].dup_candidates
    else:
        print("revised["+str(i)+"]=")
# Out:
# revised[3]=
# revised[4]=
# revised[6]=
# revised[7]=
# revised[9]=
# revised[11]=
# revised[13]=
# revised[14]=
# revised[15]=
# revised[16]=
# revised[17]=
# revised[18]=
# revised[20]=
# revised[21]=
# revised[23]=
# revised[25]=
# revised[26]=
# revised[27]=
# revised[29]=
# revised[30]=
# revised[31]=
# revised[32]=
# revised[33]=
# revised[35]=
# revised[36]=
# revised[39]=
# revised[40]=
# revised[42]=
# revised[43]=
# revised[45]=
# revised[46]=
# revised[53]=
# revised[54]=
# revised[55]=
# revised[56]=
# revised[59]=
# revised[60]=
# revised[61]=
# revised[62]=
# revised[63]=
# revised[66]=
# revised[67]=
# revised[70]=
# revised[71]=
# revised[73]=
# revised[75]=
# revised[76]=
# revised[80]=
# revised[81]=
# revised[82]=
# revised[86]=
# revised[87]=
# revised[88]=
# revised[89]=
# revised[92]=
# revised[93]=
# revised[95]=
# revised[96]=
# revised[97]=
# revised[98]=
# revised[100]=
# revised[101]=
# revised[102]=
# revised[103]=
# revised[104]=
# revised[105]=
# revised[106]=
# revised[107]=
# revised[109]=
# revised[111]=
# revised[112]=
# revised[114]=
# revised[115]=
# revised[116]=
# revised[117]=
# revised[118]=
# revised[119]=
# revised[120]=
# revised[122]=
# revised[123]=
# revised[125]=
# revised[126]=
# revised[127]=
# revised[131]=
# revised[132]=
# revised[135]=
# revised[136]=
# revised[137]=
# revised[138]=
# revised[139]=
# revised[140]=
# revised[143]=
# revised[144]=
# revised[145]=
# revised[146]=
# revised[148]=
# revised[149]=
# revised[151]=
# revised[152]=
# revised[153]=
# revised[154]=
# revised[155]=
# revised[156]=
# revised[157]=
# revised[158]=
# revised[159]=
# revised[162]=
# revised[163]=
# revised[164]=
# revised[165]=
# revised[166]=
# revised[167]=
# revised[168]=
# revised[169]=
# revised[170]=
# revised[174]=
# revised[175]=
# revised[176]=
# revised[180]=
# revised[181]=
# revised[182]=
# revised[183]=
# revised[186]=
# revised[187]=
# revised[192]=
# revised[193]=
# revised[194]=
# revised[195]=
# revised[196]=

# %%
candidates = [int(x) for x in df.iloc[OFFSET + 15].dup_candidates.split()] # Esto devuelve una lista de indices [990, 1200]
df.loc[candidates] # Esto devuelve las filas de un dataset en esa lista de indices
# Out:
#        _validation                  address advertiser_id  \
# 952                 Av Gaspar Campos al 100      17062915
# 1015                Av Gaspar Campos al 100      17062915
# 342041              Av Gaspar Campos al 100     259035443
# 342046              Av Gaspar Campos al 100     259035443
# 342796              Av Gaspar Campos al 100     259035443
# 629950                                             167582
# 629951                                             167582
# 629952                                             167582
# 630144                                             167582
# 630213                                             167582
# 630214                                             167582
#
#                                advertiser_name age bath_amnt bed_amnt  \
# 952                            Toribio Achával   0         2        2
# 1015                           Toribio Achával   0         2        2
# 342041  Sucursal Unidad de Negocios Especiales   0         2        2
# 342046  Sucursal Unidad de Negocios Especiales   0         2        2
# 342796  Sucursal Unidad de Negocios Especiales   0         2        2
# 629950                                           0         2        2
# 629951                                           0         2        2
# 629952                                           0         2        2
# 630144                                           0         2        2
# 630213                                           0         2        2
# 630214                                           0         2        2
#
#        bed_ratio       covered_ratio covered_surface  ... toilet_amnt  \
# 952      97750.0  2273.2558139534885            86.0  ...
# 1015     92000.0  2139.5348837209303            86.0  ...
# 342041   93500.0  2174.4186046511627              86  ...
# 342046   93500.0  2174.4186046511627              86  ...
# 342796   88000.0  2046.5116279069769              86  ...
# 629950   83375.0   1938.953488372093            86.0  ...
# 629951   83375.0   1938.953488372093            86.0  ...
# 629952   83375.0   1938.953488372093            86.0  ...
# 630144   92000.0  2139.5348837209303            86.0  ...
# 630213   97750.0  2273.2558139534885            86.0  ...
# 630214   97750.0  2273.2558139534885            86.0  ...
#
#                total_ratio total_surface total_surface_unit transaction  \
# 952     1602.4590163934427         122.0                 m²       Venta
# 1015    1614.0350877192982         114.0                 m²       Venta
# 342041  1532.7868852459017           122                 m²       Venta
# 342046  1532.7868852459017           122                 m²       Venta
# 342796   1543.859649122807           114                 m²       Venta
# 629950   1938.953488372093                                        Venta
# 629951   1938.953488372093                                        Venta
# 629952   1938.953488372093                                        Venta
# 630144   1295.774647887324                                        Venta
# 630213   1117.142857142857                                        Venta
# 630214   1117.142857142857                                        Venta
#
#        uncovered_surface uncovered_surface_unit  \
# 952
# 1015
# 342041
# 342046
# 342796
# 629950
# 629951
# 629952
# 630144              56.0                     m²
# 630213              89.0                     m²
# 630214              89.0                     m²
#
#                                                       url year_built  \
# 952     https://www.zonaprop.com.ar/propiedades/clasif...       2024
# 1015    https://www.zonaprop.com.ar/propiedades/clasif...       2024
# 342041   https://api.mercadolibre.com/items/MLA1391500707
# 342046   https://api.mercadolibre.com/items/MLA1391539765
# 342796   https://api.mercadolibre.com/items/MLA1391591503
# 629950  https://www.argenprop.com/departamento-en-vent...       2024
# 629951  https://www.argenprop.com/departamento-en-vent...       2024
# 629952  https://www.argenprop.com/departamento-en-vent...       2024
# 630144  https://www.argenprop.com/departamento-en-vent...       2024
# 630213  https://www.argenprop.com/departamento-en-vent...       2024
# 630214  https://www.argenprop.com/departamento-en-vent...       2024
#
#                                            dup_candidates
# 952     952 1015 342041 342046 342796 629950 629951 62...
# 1015    952 1015 342041 342046 342796 629950 629951 62...
# 342041  952 1015 342041 342046 342796 629950 629951 62...
# 342046  952 1015 342041 342046 342796 629950 629951 62...
# 342796  952 1015 342041 342046 342796 629950 629951 62...
# 629950  1014 342598 342601 342603 629950 629951 629952...
# 629951  1014 342598 342601 342603 629950 629951 629952...
# 629952  1014 342598 342601 342603 629950 629951 629952...
# 630144  1014 342598 342601 342603 629950 629951 629952...
# 630213  1014 342598 342601 342603 629950 629951 629952...
# 630214  1014 342598 342601 342603 629950 629951 629952...
#
# [11 rows x 59 columns]

# %%
# completado manual Vicky
revised[3]= df.iloc[OFFSET + 3].dup_candidates  # confirmamos que esta duplicado



revised[4]=  df.iloc[OFFSET + 4].dup_candidates # confirmamos que esta duplicado
revised[6]= "1006 2091" # el 3552 no es duplicado, es un dpto mas chico 
revised[7] = df.iloc[OFFSET + 7].dup_candidates
revised[9]= df.iloc[OFFSET + 9].dup_candidates
revised[11]=df.iloc[OFFSET + 11].dup_candidates
revised[13]=df.iloc[OFFSET + 13].dup_candidates 
revised[14]= df.iloc[OFFSET + 14].dup_candidates  # volver a mirarlo, tiene muchos registros, a lo mejor algunos no son duplicados
revised[15]=  # tiene muchos registros, algunos tienen metros totales diferentes. Da para revisar mejor
revised[16]=
revised[17]=
revised[18]=
revised[20]=
revised[21]=
revised[23]=
revised[25]=
revised[26]=
revised[27]=
revised[29]=
revised[30]=
revised[31]=
revised[32]=
revised[33]=
revised[35]=
revised[36]=
revised[39]=
revised[40]=
revised[42]=
revised[43]=
revised[45]=
revised[46]=
# Completado manual Ivan
revised[53]=
revised[54]=
revised[55]=
revised[56]=
revised[59]=
revised[60]=
revised[61]=
revised[62]=
revised[63]=
revised[66]=
revised[67]=
revised[70]=
revised[71]=
revised[73]=
revised[75]=
revised[76]=
revised[80]=
revised[81]=
revised[82]=
revised[86]=
revised[87]=
revised[88]=
revised[89]=
revised[92]=
revised[93]=
revised[95]=
revised[96]=
revised[97]=
revised[98]=

# %%
candidates = [int(x) for x in df.iloc[1003].dup_candidates.split()] # Esto devuelve una lista de indices [990, 1200]
df.loc[candidates] # Esto devuelve las filas de un dataset en esa lista de indices
# muestra las descripciones de cada aviso junto con sus indidces...
# Out:
#      _validation                                            address  \
# 1003              Leandro N. Alem & 25 de Mayo, Dock Sud, Provin...
# 7968              Leandro N. Alem & 25 de Mayo, Dock Sud, Provin...
#
#      advertiser_id advertiser_name age bath_amnt bed_amnt bed_ratio  \
# 1003    1285790463                             3
# 7968    1285790463                             3
#
#            covered_ratio covered_surface  ... toilet_amnt total_ratio  \
# 1003  1714.2857142857142              70  ...                   600.0
# 7968   928.5714285714286              70  ...                   325.0
#
#      total_surface total_surface_unit transaction uncovered_surface  \
# 1003           200                 m²       Venta
# 7968           200                 m²       Venta
#
#      uncovered_surface_unit                                               url  \
# 1003                         https://api.mercadolibre.com/items/MLA1408943916
# 7968                         https://api.mercadolibre.com/items/MLA1409594620
#
#      year_built dup_candidates
# 1003                 1003 7968
# 7968                 1003 7968
#
# [2 rows x 59 columns]

# %%
# codigo para obtener la grilla
candidates = [int(x) for x in df.iloc[OFFSET + i].dup_candidates.split()] # Esto devuelve una lista de indices [990, 1200]
df.loc[candidates] # Esto devuelve las filas de un dataset en esa lista de indices

# %%
# muestra las descripciones de cada aviso junto con sus indidces...
for idx, desc in zip(candidates,df.loc[candidates]['description']):
    print(f' {idx}   ******************')
    print(desc)
