# %%
import pandas as pd
import rdflib
import numpy

df = pd.read_csv('dataset/raw.csv.gz', dialect='excel', keep_default_na=False, dtype=str, index_col=0)

DESDE = 1000
HASTA = 1100
subset_df = df.iloc[DESDE:HASTA]


contador = 0
for i in range(DESDE, HASTA):
    if(len(df.loc[i].dup_candidates.split())<2):contador+=1

print(contador)
# Out:
# 40

# %%
df.loc[1088].dup_candidates
# Out:
# '1088 2048 2210 2228 2353 2478 2654 2672 2923 3262 3566 346843 346976 347052 348472 348475 348801'

# %%
# inicializo la lista con cadenas vacias que significa que aun no se reviso
revised = ['']*200

OFFSET =1000 # para que el indice de la lista sea el mismo que el del dataframe
for i in range(0,199):
    if(len(df.loc[i+OFFSET].dup_candidates.split())<2):
        revised[i] = df.loc[i+OFFSET].dup_candidates
    else:
        print("revised["+str(i)+"]=")

# %%
posicionPorControlar = 98

# %%
candidates = [int(x) for x in df.iloc[OFFSET + posicionPorControlar].dup_candidates.split()] # Esto devuelve una lista de indices [990, 1200]
df.loc[candidates] # Esto devuelve las filas de un dataset en esa lista de indices
# Out:
#        _validation        address advertiser_id  \
# 1098                Paraguay 1000     207423169
# 377972              Paraguay 1000      30003153
#
#                                           advertiser_name   age bath_amnt  \
# 1098    FRANCISCO D'ATRI CPMCAL 45 / LEONEL D'ATRI CUC...  14.0         2
# 377972                                    RE/MAX TITANIUM  14.0         2
#
#        bed_amnt           bed_ratio      covered_ratio covered_surface  ...  \
# 1098          3  36666.666666666664  924.3697478991596             119  ...
# 377972        3  36666.666666666664  924.3697478991596           119.0  ...
#
#        toilet_amnt        total_ratio total_surface total_surface_unit  \
# 1098                924.3697478991596           119                 m²
# 377972              924.3697478991596         119.0                 m²
#
#        transaction uncovered_surface uncovered_surface_unit  \
# 1098         Venta
# 377972       Venta
#
#                                                       url year_built  \
# 1098     https://api.mercadolibre.com/items/MLA1653945392       2010
# 377972  https://www.zonaprop.com.ar/propiedades/clasif...       2010
#
#        dup_candidates
# 1098      1098 377972
# 377972    1098 377972
#
# [2 rows x 59 columns]

# %%
# muestra las descripciones de cada aviso junto con sus indidces...
descripcionesPorRevisar = [int(x) for x in df.iloc[OFFSET + posicionPorControlar].dup_candidates.split()]
print(descripcionesPorRevisar)
for idx, desc in zip(descripcionesPorRevisar,df.loc[descripcionesPorRevisar]['description']):
    print(f' {idx}   ******************')
    print(desc)
    print()
# Out:
# [1098, 377972]
#  1098   ******************
# Corredor Responsable: FRANCISCO D'ATRI CPMCAL 45 / LEONEL D'ATRI CUCICBA 6618 -
# Contacto: Carolina Tomas
# Hermosa casa sobre lote propio de 7,8 x 17.
#
# Excelente ubicación, sobre la calle Paraguay al 1000, a media cuadra de la Av. Pres. B. Rivadavia y a una cuadra de la Av. Cabildo.
# A 6 cuadras del zona comercial de V. Alsina, donde podes encontrar restaurantes, comercios de todo tipo, bancos, colegios y plazas.
# Cercanía a las paradas de colectivos de las líneas: 20, 37, 79, 85 y 178.
# Fácil acceso al transito y a tan solo 5 minutos del puente Alsina, acceso a Caba.
#
# Distribución de la propiedad:
#
# Planta baja:
# *Cochera.
# *Se ingresa por el amplio living-comedor con ventana al frente y ventana al patio (ventilación cruzada), este ambiente cuenta con A/A.
# *Baño completo con bañadera.
# *Cocina-comedor con muebles bajo mesada, horno empotrado y espacio de alacena.
# *Lavadero independiente.
# *Acceso a planta alta y salida al patio.
# *Espacio de guardado bajo escalera.
#
# Planta alta:
# *Ambiente amplio que se puede usar como salón de juegos con salida al balcón.
# *Habitación principal con ventana al frente, cuenta con placard y tiene acceso directo al baño de planta alta.
# *Baño completo con hidromasaje, muy cómodo.
# *Segunda habitación con doble placard y ventana al contrafrente.
# *Tipo altillo se encuentra el tercer dormitorio con doble ventana ( se podrían hacer 2 dormitorios), este espacio cuenta con espacio de guardado.
#
# La propiedad esta en un muy buen estado de mantenimiento, todas las aberturas son de madera de calidad.
#
# **NO DUDES EN VISITAR ESTA HERMOSA PROPIEDAD**
# Remax Argentina S.R.L. no ejerce el corretaje inmobiliario. El presente sitio web es una plataforma en donde cada oficina inmobiliaria independiente que contrata los servicios RE/MAX puede publicar las propiedades a su cargo. Cada oficina es de propiedad y gestión independiente, por lo que Remax Argentina S.R.L no interviene en los datos de la publicación, en la operación inmobiliaria, ni en la confección y/o firma del boleto de compraventa y/o escritura y/o contrato de alquiler. En cumplimiento de las leyes vigentes que regulan el corretaje inmobiliario, Ley Nacional 25.028, Ley 22.802 de Lealtad Comercial, Ley 24.240 de Defensa al Consumidor, las normas del Código Civil y Comercial de la Nación y Constitucionales, los agentes/gestores NO ejercen el corretaje inmobiliario. Todas las operaciones inmobiliarias son objeto de intermediación y conclusión por parte del corredor público inmobiliario colegiado a cargo de la publicación, cuyos datos se exhiben en la presente. La presente publicación describe las características esenciales del inmueble, debiéndose consultar al corredor público inmobiliario responsable de la operación por la eventual actualización de las medidas, descripciones arquitectónicas y funcionales, valores de expensas, servicios, impuestos, precios y demás información, cuyos valores son aproximados.
# Comprá la casa que querés! No la que podés. Accedé a un préstamo por hasta el 30% del valor de esta propiedad. Simulá tu cuota en Lendar.
#
#  377972   ******************
# Corredor Responsable: FRANCISCO D'ATRI CPMCAL 45 / LEONEL D'ATRI CUCICBA 6618 - Contacto: Carolina Tomas - MLS ID # Hermosa casa sobre lote propio de 7,8 x 17. Excelente ubicación, sobre la calle Paraguay al 1000, a media cuadra de la Av. Pres. B. Rivadavia y a una cuadra de la Av. Cabildo. A 6 cuadras del zona comercial de V. Alsina, donde podes encontrar restaurantes, comercios de todo tipo, bancos, colegios y plazas. Cercanía a las paradas de colectivos de las líneas: 20, 37, 79, 85 y 178. Fácil acceso al transito y a tan solo 5 minutos del puente Alsina, acceso a Caba. Distribución de la propiedad: Planta baja: *Cochera. *Se ingresa por el amplio living-comedor con ventana al frente y ventana al patio (ventilación cruzada), este ambiente cuenta con A/A. *Baño completo con bañadera. *Cocina-comedor con muebles bajo mesada, horno empotrado y espacio de alacena. *Lavadero independiente. *Acceso a planta alta y salida al patio. *Espacio de guardado bajo escalera. Planta alta: *Ambiente amplio que se puede usar como salón de juegos con salida al balcón. *Habitación principal con ventana al frente, cuenta con placard y tiene acceso directo al baño de planta alta. *Baño completo con hidromasaje, muy cómodo. *Segunda habitación con doble placard y ventana al contrafrente. *Tipo altillo se encuentra el tercer dormitorio con doble ventana ( se podrían hacer 2 dormitorios), este espacio cuenta con espacio de guardado. La propiedad esta en un muy buen estado de mantenimiento, todas las aberturas son de madera de calidad. **NO DUDES EN VISITAR ESTA HERMOSA PROPIEDAD** Remax Argentina S.R.L. no ejerce el corretaje inmobiliario. El presente sitio web es una plataforma en donde cada oficina inmobiliaria independiente que contrata los servicios RE/MAX puede publicar las propiedades a su cargo. Cada oficina es de propiedad y gestión independiente, por lo que Remax Argentina S.R.L no interviene en los datos de la publicación, en la operación inmobiliaria, ni en la confección y/o firma del boleto de compraventa y/o escritura y/o contrato de alquiler. En cumplimiento de las leyes vigentes que regulan el corretaje inmobiliario, Ley Nacional 25.028, Ley 22.802 de Lealtad Comercial, Ley 24.240 de Defensa al Consumidor, las normas del Código Civil y Comercial de la Nación y Constitucionales, los agentes/gestores NO ejercen el corretaje inmobiliario. Todas las operaciones inmobiliarias son objeto de intermediación y conclusión por parte del corredor público inmobiliario colegiado a cargo de la publicación, cuyos datos se exhiben en la presente. La presente publicación describe las características esenciales del inmueble, debiéndose consultar al corredor público inmobiliario responsable de la operación por la eventual actualización de las medidas, descripciones arquitectónicas y funcionales, valores de expensas, servicios, impuestos, precios y demás información, cuyos valores son aproximados. Comprá la casa que querés! No la que podés. Accedé a un préstamo por hasta el 30% del valor de esta propiedad. Simulá tu cuota en Lendar

# %%
# completado manual Vicky
revised[3]= df.iloc[OFFSET + 3].dup_candidates  # confirmamos que esta duplicado



revised[4]=  df.iloc[OFFSET + 4].dup_candidates # confirmamos que esta duplicado
revised[6]= "1006 2091" # el 3552 no es duplicado, es un dpto mas chico 
revised[7]= df.iloc[OFFSET + 7].dup_candidates
revised[9]= df.iloc[OFFSET + 9].dup_candidates
revised[11]= df.iloc[OFFSET + 11].dup_candidates
revised[13]= df.iloc[OFFSET + 13].dup_candidates 
revised[14]= df.iloc[OFFSET + 14].dup_candidates  
revised[15]= df.iloc[OFFSET + 15].dup_candidates  
revised[16]= df.iloc[OFFSET + 16].dup_candidates  
revised[17]= df.iloc[OFFSET + 17].dup_candidates 
revised[18]= df.iloc[OFFSET + 18].dup_candidates
revised[20]= df.iloc[OFFSET + 20].dup_candidates
revised[21]= df.iloc[OFFSET + 21].dup_candidates
revised[23]= df.iloc[OFFSET + 23].dup_candidates
revised[25]= df.iloc[OFFSET + 25].dup_candidates
revised[26]= "1026 610908 612614" # el age es sustancialmente diferente para los casos que se quitaron
revised[27]= df.iloc[OFFSET + 27].dup_candidates
revised[29]= df.iloc[OFFSET + 29].dup_candidates
revised[30]= df.iloc[OFFSET + 30].dup_candidates
revised[31]= df.iloc[OFFSET + 31].dup_candidates
revised[32]= df.iloc[OFFSET + 32].dup_candidates
revised[33]= df.iloc[OFFSET + 33].dup_candidates
revised[35]= df.iloc[OFFSET + 35].dup_candidates
revised[36]= df.iloc[OFFSET + 36].dup_candidates
revised[39]= df.iloc[OFFSET + 39].dup_candidates
revised[40]= df.iloc[OFFSET + 40].dup_candidates
revised[42]= df.iloc[OFFSET + 42].dup_candidates
revised[43]= df.iloc[OFFSET + 43].dup_candidates   
revised[45]= df.iloc[OFFSET + 45].dup_candidates
revised[46]= df.iloc[OFFSET + 46].dup_candidates
# Completado manual Ivan
revised[53]= df.iloc[OFFSET + 53].dup_candidates
revised[54]= df.iloc[OFFSET + 54].dup_candidates # todos corresponden al mismo edificio pero a ningun departamente especifico. Es un emprendimiento inmobiliario
revised[55]= df.iloc[OFFSET + 55].dup_candidates
revised[56]= df.iloc[OFFSET + 56].dup_candidates
revised[59]= df.iloc[OFFSET + 59].dup_candidates
revised[60]= df.iloc[OFFSET + 60].dup_candidates
revised[61]= df.iloc[OFFSET + 61].dup_candidates
revised[62]= df.iloc[OFFSET + 62].dup_candidates
revised[63]= df.iloc[OFFSET + 63].dup_candidates
revised[66]= "1066, 2558, 2560, 2562, 612538" # Se trata de 3 departamentos diferentes. Se identifican 3 distribuciones diferentes de cocina, baño, etc en imagenes. Solo se han excluido los que no se corresponden con el inmueble 1066 (383716, 609086, 609422, 610835, 611336, 611350, 611361, 611675, 612537)
revised[67]= df.iloc[OFFSET + 67].dup_candidates
revised[70]= df.iloc[OFFSET + 70].dup_candidates
revised[71]= df.iloc[OFFSET + 71].dup_candidates
revised[73]= df.iloc[OFFSET + 73].dup_candidates
revised[75]= df.iloc[OFFSET + 75].dup_candidates
revised[76]= df.iloc[OFFSET + 76].dup_candidates
revised[80]= df.iloc[OFFSET + 80].dup_candidates # todos corresponden al mismo edificio pero a ningun departamente especifico. Es un emprendimiento inmobiliario
revised[81]= df.iloc[OFFSET + 81].dup_candidates
revised[82]= df.iloc[OFFSET + 81].dup_candidates
revised[86]= df.iloc[OFFSET + 81].dup_candidates
revised[87]= df.iloc[OFFSET + 87].dup_candidates
revised[88]= df.iloc[OFFSET + 88].dup_candidates
revised[89]= "1088, 348801" # Se trata de varios terrenos publicados en dos plataformas diferentes. Se excluye a todos los que no coinciden con superficie/precio y estan en misma platarma (2048 2210 2228 2353 2478 2654 2672 2923 3262 3566 346843 346976 347052 348472 348475)
revised[92]= df.iloc[OFFSET + 92].dup_candidates
revised[93]= df.iloc[OFFSET + 93].dup_candidates
revised[95]= df.iloc[OFFSET + 95].dup_candidates
revised[96]= df.iloc[OFFSET + 96].dup_candidates
revised[97]= df.iloc[OFFSET + 97].dup_candidates
revised[98]= df.iloc[OFFSET + 98].dup_candidates

# %%
candidates = [int(x) for x in df.iloc[1003].dup_candidates.split()] # Esto devuelve una lista de indices [990, 1200]
df.loc[candidates] # Esto devuelve las filas de un dataset en esa lista de indices
# muestra las descripciones de cada aviso junto con sus indidces...
# Out:
#      _validation                                            address  \
# 1003              Leandro N. Alem & 25 de Mayo, Dock Sud, Provin...
# 7968              Leandro N. Alem & 25 de Mayo, Dock Sud, Provin...
#
#      advertiser_id advertiser_name age bath_amnt bed_amnt bed_ratio  \
# 1003    1285790463                             3
# 7968    1285790463                             3
#
#            covered_ratio covered_surface  ... toilet_amnt total_ratio  \
# 1003  1714.2857142857142              70  ...                   600.0
# 7968   928.5714285714286              70  ...                   325.0
#
#      total_surface total_surface_unit transaction uncovered_surface  \
# 1003           200                 m²       Venta
# 7968           200                 m²       Venta
#
#      uncovered_surface_unit                                               url  \
# 1003                         https://api.mercadolibre.com/items/MLA1408943916
# 7968                         https://api.mercadolibre.com/items/MLA1409594620
#
#      year_built dup_candidates
# 1003                 1003 7968
# 7968                 1003 7968
#
# [2 rows x 59 columns]

# %%
# codigo para obtener la grilla
candidates = [int(x) for x in df.iloc[OFFSET + i].dup_candidates.split()] # Esto devuelve una lista de indices [990, 1200]
df.loc[candidates] # Esto devuelve las filas de un dataset en esa lista de indices

# %%
# muestra las descripciones de cada aviso junto con sus indidces...
for idx, desc in zip(candidates,df.loc[candidates]['description']):
    print(f' {idx}   ******************')
    print(desc)
